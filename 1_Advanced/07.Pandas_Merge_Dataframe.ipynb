# %%
#importing Data Analysis Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#loading the dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

#data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_US_software_pivot = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')

df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_US_software_pivot.plot(kind='line', title='Software Job Titles in the US Over Months', xlabel='2023', ylabel='Number of Job Postings')
# Out:
# <Axes: title={'center': 'Software Job Titles in the US Over Months'}, xlabel='2023', ylabel='Number of Job Postings'>
